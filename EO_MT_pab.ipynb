# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
xl = pd.ExcelFile('02_07.xlsx')
xl.sheet_names
# Out:
# ['Лист1', 'Лист2']

# %%
df = xl.parse('Лист1')

# %%
df.columns
# Out:
# Index(['id', 'miasto', 'rok', 'kod_choroby', 'Liczba_zach', 'AOZ',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
sns.relplot(x = "Liczba_zach", y = "kod_choroby", data= df)
plt.savefig('visualization_for_all.png',dpi = 300, bbox_inches='tight')

# %%
df['miasto'].value_counts()
# Out:
# Lębork     110
# Kwidzyn    110
# Malbork    110
# Name: miasto, dtype: int64

# %%
data2014 = df.loc[df['rok'] == 2014]
plt.figure(figsize=(30, 10))#mogu podelit pod wzgledem roku
plt.scatter(
    x = df['kod_choroby'], 
    y = df['miasto'], 
    s=df['Liczba_zach']*40, 
    cmap="Accent", 
    alpha=0.6, 
    edgecolors="white", 
    linewidth=2);
plt.savefig('All_years.png', dpi = 300, bbox_inches='tight')

# %%
df['miasto'].value_counts()
# Out:
# Lębork     110
# Kwidzyn    110
# Malbork    110
# Name: miasto, dtype: int64

# %%
mal =df.loc[df["miasto"] == 'Malbork']

# %%
plt.figure(figsize=(20, 20))
df['kod_choroby']=pd.Categorical(df['kod_choroby'])
plt.scatter(
    x = df['kod_choroby'], 
    y = df['rok'], 
    s=df['Liczba_zach']*30,
    c=df['kod_choroby'].cat.codes, 
    cmap="Accent", 
    alpha=0.6, 
    edgecolors="white", 
    linewidth=2);

# %%
mal = df.loc[df['miasto'] == 'Malbork']
kwi = df.loc[df['miasto'] == 'Kwidzyn']
leb = df.loc[df['miasto'] == 'Lębork']

# %%
plt.figure(figsize=(20, 10))
mal['kod_choroby']=pd.Categorical(mal['kod_choroby'])
plt.scatter(
    x = mal['kod_choroby'], 
    y = mal['rok'], 
    s=mal['Liczba_zach']*35,
    c=mal['kod_choroby'].cat.codes, 
    cmap="Accent", 
    alpha=0.6, 
    edgecolors="white", 
    linewidth=2);
plt.title('Malbork')
plt.savefig('Liczba_zach_Malbork.png',dpi = 300, bbox_inches='tight')
# Out:
# <ipython-input-18-ecb968ccb66a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mal['kod_choroby']=pd.Categorical(mal['kod_choroby'])

# %%
plt.figure(figsize=(20, 10))
kwi['kod_choroby']=pd.Categorical(kwi['kod_choroby'])
plt.scatter(
    x = kwi['kod_choroby'], 
    y = kwi['rok'], 
    s=kwi['Liczba_zach']*30,
    c=kwi['kod_choroby'].cat.codes, 
    cmap="Accent", 
    alpha=0.6, 
    edgecolors="white", 
    linewidth=2);
plt.title('Kwidzyn')
plt.savefig('Liczba_zach_Kwidzyn.png',dpi = 300, bbox_inches='tight')
# Out:
# <ipython-input-19-e35352add45c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kwi['kod_choroby']=pd.Categorical(kwi['kod_choroby'])

# %%
plt.figure(figsize=(20, 10))
leb['kod_choroby']=pd.Categorical(leb['kod_choroby'])
plt.scatter(
    x = leb['kod_choroby'], 
    y = leb['rok'], 
    s=leb['Liczba_zach']*30,
    c=leb['kod_choroby'].cat.codes, 
    cmap="Accent", 
    alpha=0.6, 
    edgecolors="white", 
    linewidth=2);
plt.title('Lębork')
plt.savefig('Liczba_zach_Lębork.png',dpi = 300, bbox_inches='tight')
# Out:
# <ipython-input-20-2ebc10e34ead>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   leb['kod_choroby']=pd.Categorical(leb['kod_choroby'])

# %%
xl.sheet_names
df2 = xl.parse('Лист2')

# %%
sns.lineplot(data= mal1, x="rok", y="AOZ", legend=False, sizes=(20, 2000))
plt.savefig('Malbork_aoz.png', dpi =300)

# %%
sns.lineplot(data= kwi1, x="rok", y="AOZ", legend=False, sizes=(20, 2000))
plt.savefig('Malbork_aoz.png', dpi =300)

# %%
sns.lineplot(data= leb1, x="rok", y="AOZ", legend=False, sizes=(20, 2000))
plt.savefig('Malbork_aoz.png', dpi =300)

# %%
sns.lineplot(data= df2, x="rok", y="AOZ",hue = 'miasto',legend=True, sizes=(20, 2000))
plt.title('AOZ_value_for_all_cities')
plt.savefig('generall_aoz.png', dpi =300)

# %%
df.columns
# Out:
# Index(['id', 'miasto', 'rok', 'kod_choroby', 'Liczba_zach', 'AOZ',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
# !pip install Plotly 
import plotly.graph_objects as go

# %%
sns.set_style("white") #simple 2Dmodel for region
sns.kdeplot(x=mal.rok, y=mal.Liczba_zach)
plt.show()

# %%
sns.set_style("white") #simple 2Dmodel for region
sns.kdeplot(x=leb.rok, y=leb.Liczba_zach)
plt.show()

# %%
sns.set_style("white") #simple 2Dmodel for region
sns.kdeplot(x=kwi.rok, y=kwi.Liczba_zach)
plt.show()

# %%
sns.set_theme(style="ticks")
g = sns.jointplot(
    data=df,
    x="rok", y="Liczba_zach", hue="miasto",
    kind="kde",
)

# %%
sns.set_theme(style="ticks")
g = sns.jointplot(
    data=df2,
    x="rok", y="AOZ", hue="miasto",
    kind="kde",
)
plt.figure(figsize=(30, 50))

# %%
sns.displot(
    data=mal,
    x="Liczba_zach", hue="kod_choroby",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.displot(
    data=kwi,
    x="Liczba_zach", hue="kod_choroby",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)
plt.title('Kwidzyn')
# Out:
# Text(0.5, 1.0, 'Kwidzyn')

# %%
sns.displot(
    data=leb,
    x="Liczba_zach", hue="kod_choroby",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.displot(
    data=df2,
    x="AOZ", hue="miasto",
    kind="kde", height=6,
    multiple="fill", clip=(0, None),
    palette="ch:rot=-.25,hue=1,light=.75",
)

# %%
sns.lmplot(x="rok", y="AOZ", col="miasto", data=df2,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
sns.lmplot(x="rok", y="Liczba_zach", col="miasto", hue = 'kod_choroby', data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %%
g = sns.lmplot(
    data=df2,
    x="rok", y="AOZ", hue="miasto",
    height=5
)

# %%
g = sns.lmplot(
    data=df,
    x="rok", y="Liczba_zach", hue="miasto",
    height=5
)
